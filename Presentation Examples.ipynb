# %%
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)  # Ignore deprecation warnings

import model
import inference
import magenta.music as mm
# Out:
# Using TensorFlow backend.
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# # Demo Songs
#
# ### Iron Maiden
# Fear of the Dark
#
# ### Black Sabbath
# Iron Man (Original, and generated)
#
# ### Michael Jackson
# Beat It
# Smooth Criminal
#
# ### Joe Satriani
# Surfing With the Alien
#
# ### Tetris
# Tetris Theme Song

# %% [markdown]
# # Iron Maiden: Fear of the Dark

# %%
song_name = "Iron_Maiden_Fear_of_the_Dark_accompany.mid" 

# Load the song
midi = None
with open('./data/159_outputs/{}'.format(song_name), 'rb') as midi_file:
    midi = midi_file.read()
note_seq = mm.midi_to_sequence_proto(midi)

# Plot the song's sequence
mm.plot_sequence(note_seq)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1064">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a3e117f2-86d4-47fc-ad25-2d12a7b175ab" data-root-id="1001"></div>

# %% [markdown]
# # Black Sabbath: Iron Man (Generated Melody)

# %%
song_name = "Iron_Man_(unstitched)_accompany.mid" 

# Load the song
midi = None
with open('./data/159_outputs/{}'.format(song_name), 'rb') as midi_file:
    midi = midi_file.read()
note_seq = mm.midi_to_sequence_proto(midi)

# Plot the song's sequence
mm.plot_sequence(note_seq)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1372">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f58cdd23-8605-44d0-99bd-6abce26dc471" data-root-id="1309"></div>

# %% [markdown]
# # Black Sabbath: Iron Man (Original Melody)

# %%
song_name = "Iron_Man_accompany.mid" 

# Load the song
midi = None
with open('./data/159_outputs/{}'.format(song_name), 'rb') as midi_file:
    midi = midi_file.read()
note_seq = mm.midi_to_sequence_proto(midi)

# Plot the song's sequence
mm.plot_sequence(note_seq)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1544">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c4ad6cf1-8a6c-4ee5-963c-2fb6a9b640b2" data-root-id="1481"></div>

# %% [markdown]
# # Michael Jackson: Beat It

# %%
song_name = "Michael_Jackson_Beat_It_accompany.mid" 

# Load the song
midi = None
with open('./data/159_outputs/{}'.format(song_name), 'rb') as midi_file:
    midi = midi_file.read()
note_seq = mm.midi_to_sequence_proto(midi)

# Plot the song's sequence
mm.plot_sequence(note_seq)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1728">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="14516d71-7c9c-49f3-be7f-889e4d259d0e" data-root-id="1665"></div>

# %% [markdown]
# # Michael Jackson: Smooth Criminal

# %%
song_name = "Michael_Jackson_Smooth_Criminal_accompany.mid"

# Load the song
midi = None
with open('./data/159_outputs/{}'.format(song_name), 'rb') as midi_file:
    midi = midi_file.read()
note_seq = mm.midi_to_sequence_proto(midi)

# Plot the song's sequence
mm.plot_sequence(note_seq)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1924">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="33befc4c-3486-4c44-ae54-a3e25de32e7e" data-root-id="1861"></div>

# %% [markdown]
# # Joe Satriani: Surfing With the Alien

# %%
song_name = "Surfing_with_The_Alien_accompany.mid" 

# Load the song
midi = None
with open('./data/159_outputs/{}'.format(song_name), 'rb') as midi_file:
    midi = midi_file.read()
note_seq = mm.midi_to_sequence_proto(midi)

# Plot the song's sequence
mm.plot_sequence(note_seq)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2352">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="484020ec-51c7-4bc1-ad68-9b6ba3b25ca8" data-root-id="2289"></div>

# %% [markdown]
# # Tetris

# %%
song_name = "Tetris_accompany.mid" 

# Load the song
midi = None
with open('./data/159_outputs/{}'.format(song_name), 'rb') as midi_file:
    midi = midi_file.read()
note_seq = mm.midi_to_sequence_proto(midi)

# Plot the song's sequence
mm.plot_sequence(note_seq)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2584">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="09df5fed-9355-476f-9c18-b06adbc840a3" data-root-id="2521"></div>
